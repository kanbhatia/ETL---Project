# %%
# Importing required modules
import pandas as pd
from sqlalchemy import inspect, create_engine

# %%
# Location of csv documents
Cad_trending_loc = "CSV files/CAvideos.csv"
Subscribers_loc = "CSV files/channels.csv"

# %%
# Reading csv files using pandas
cad_trend = pd.read_csv(Cad_trending_loc)
subscribers = pd.read_csv(Subscribers_loc)

# %%
# Cleaning Data for trending videos
cad_trend = cad_trend[["channel_title","title", "category_id","views","likes","dislikes","comment_count"]]
cad_trend.head()
# Out:
#   channel_title                                              title  \
# 0    EminemVEVO         Eminem - Walk On Water (Audio) ft. Beyoncé
# 1     iDubbbzTV                      PLUSH - Bad Unboxing Fan Mail
# 2  Rudy Mancuso  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3      nigahiga                           I Dare You: GOING BALD!?
# 4    Ed Sheeran        Ed Sheeran - Perfect (Official Music Video)
#
#    category_id     views    likes  dislikes  comment_count
# 0           10  17158579   787425     43420         125882
# 1           23   1014651   127794      1688          13030
# 2           23   3191434   146035      5339           8181
# 3           24   2095828   132239      1989          17518
# 4           10  33523622  1634130     21082          85067

# %%
# Changing column names
cad_trend.rename(columns = {"channel_title": "Channel Name", "title": "Video Name", "category_id":"Category ID",\
                           "views":"Views","likes":"Likes","dislikes":"Dislikes","comment_count":\
                            "Number of Comments"},inplace = True)
cad_trend.head()
# Out:
#    Channel Name                                         Video Name  \
# 0    EminemVEVO         Eminem - Walk On Water (Audio) ft. Beyoncé
# 1     iDubbbzTV                      PLUSH - Bad Unboxing Fan Mail
# 2  Rudy Mancuso  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3      nigahiga                           I Dare You: GOING BALD!?
# 4    Ed Sheeran        Ed Sheeran - Perfect (Official Music Video)
#
#    Category ID     Views    Likes  Dislikes  Number of Comments
# 0           10  17158579   787425     43420              125882
# 1           23   1014651   127794      1688               13030
# 2           23   3191434   146035      5339                8181
# 3           24   2095828   132239      1989               17518
# 4           10  33523622  1634130     21082               85067

# %%
# Cleaning Data for subscribers videos
subscribers = subscribers[["title","category_name","followers","videos"]]
subscribers.head()
# Out:
#              title  category_name  followers  videos
# 0        PewDiePie  Entertainment   69896406    3649
# 1         T-Series          Music   69471946   12820
# 2    Justin Bieber  Entertainment   41858494     132
# 3  5-Minute Crafts  Howto & Style   40474509    2350
# 4              WWE         Sports   36301947   37928

# %%
# Changing column names
subscribers.rename(columns = {"title": "Channel Name","category_name":"Category Name",\
                              "followers":"Followers", "videos": "Number of Videos"},inplace = True)
subscribers.head()
# Out:
#       Channel Name  Category Name  Followers  Number of Videos
# 0        PewDiePie  Entertainment   69896406              3649
# 1         T-Series          Music   69471946             12820
# 2    Justin Bieber  Entertainment   41858494               132
# 3  5-Minute Crafts  Howto & Style   40474509              2350
# 4              WWE         Sports   36301947             37928

# %%
# Merging documents
Youtube = pd.merge(cad_trend,subscribers, on ="Channel Name")
Youtube.head()
# Out:
#   Channel Name                                         Video Name  \
# 0   EminemVEVO         Eminem - Walk On Water (Audio) ft. Beyoncé
# 1   EminemVEVO         Eminem - Walk On Water (Audio) ft. Beyoncé
# 2   EminemVEVO         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3   EminemVEVO         Eminem - Walk On Water (Audio) ft. Beyoncé
# 4   EminemVEVO  Walk On Water/Stan/Love The Way You Lie (Medle...
#
#    Category ID     Views   Likes  Dislikes  Number of Comments Category Name  \
# 0           10  17158579  787425     43420              125882         Music
# 1           10  20539417  840642     47715              124236         Music
# 2           10  22702386  869304     50018              123235         Music
# 3           10  24578152  891283     51978              125444         Music
# 4           10   1535199  153770      2439               16875         Music
#
#    Followers  Number of Videos
# 0   26572348                82
# 1   26572348                82
# 2   26572348                82
# 3   26572348                82
# 4   26572348                82

# %% [markdown]
# # Connect to local database

# %%
rds_connection_string = "postgres:postgres@localhost:5432/youtube_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['youtube']

# %%
Youtube.to_sql(name='youtube', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1223                     self.dialect.do_executemany(
# -> 1224                         cursor, statement, parameters, context
#    1225                     )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     724         else:
# --> 725             cursor.executemany(statement, parameters)
#     726
#
# UndefinedColumn: column "Views" of relation "youtube" does not exist
# LINE 1: ...ube ("Channel Name", "Video Name", "Category ID", "Views", "...
#                                                              ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-11-1d21669ecaaf> in <module>
# ----> 1 Youtube.to_sql(name='youtube', con=engine, if_exists='append', index=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2529         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2530                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2531                    dtype=dtype, method=method)
#    2532
#    2533     def to_pickle(self, path, compression='infer',
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     458     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     459                       index_label=index_label, schema=schema,
# --> 460                       chunksize=chunksize, dtype=dtype, method=method)
#     461
#     462
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1172                          schema=schema, dtype=dtype)
#    1173         table.create()
# -> 1174         table.insert(chunksize, method=method)
#    1175         if (not name.isdigit() and not name.islower()):
#    1176             # check for potentially case sensitivity issues (GH7815)
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     684
#     685                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 686                 exec_insert(conn, keys, chunk_iter)
#     687
#     688     def _query_iterator(self, result, chunksize, columns, coerce_float=True,
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     597         """
#     598         data = [dict(zip(keys, row)) for row in data_iter]
# --> 599         conn.execute(self.table.insert(), data)
#     600
#     601     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     986             raise exc.ObjectNotExecutableError(object_)
#     987         else:
# --> 988             return meth(self, multiparams, params)
#     989
#     990     def _execute_function(self, func, multiparams, params):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     285     def _execute_on_connection(self, connection, multiparams, params):
#     286         if self.supports_execution:
# --> 287             return connection._execute_clauseelement(self, multiparams, params)
#     288         else:
#     289             raise exc.ObjectNotExecutableError(self)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1105             distilled_params,
#    1106             compiled_sql,
# -> 1107             distilled_params,
#    1108         )
#    1109         if self._has_events or self.engine._has_events:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1246         except BaseException as e:
#    1247             self._handle_dbapi_exception(
# -> 1248                 e, statement, parameters, cursor, context
#    1249             )
#    1250
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1464                 util.raise_from_cause(newraise, exc_info)
#    1465             elif should_wrap:
# -> 1466                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1467             else:
#    1468                 util.reraise(*exc_info)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     381     exc_type, exc_value, exc_tb = exc_info
#     382     cause = exc_value if exc_value is not exception else None
# --> 383     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     384
#     385
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     126             value.__cause__ = cause
#     127         if value.__traceback__ is not tb:
# --> 128             raise value.with_traceback(tb)
#     129         raise value
#     130
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1222                 if not evt_handled:
#    1223                     self.dialect.do_executemany(
# -> 1224                         cursor, statement, parameters, context
#    1225                     )
#    1226             elif not parameters and context.no_parameters:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     723             extras.execute_batch(cursor, statement, parameters)
#     724         else:
# --> 725             cursor.executemany(statement, parameters)
#     726
#     727     @util.memoized_instancemethod
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "Views" of relation "youtube" does not exist
# LINE 1: ...ube ("Channel Name", "Video Name", "Category ID", "Views", "...
#                                                              ^
#
# [SQL: INSERT INTO youtube ("Channel Name", "Video Name", "Category ID", "Views", "Likes", "Dislikes", "Number of Comments", "Category Name", "Followers", "Number of Videos") VALUES (%(Channel Name)s, %(Video Name)s, %(Category ID)s, %(Views)s, %(Likes)s, %(Dislikes)s, %(Number of Comments)s, %(Category Name)s, %(Followers)s, %(Number of Videos)s)]
# [parameters: ({'Channel Name': 'EminemVEVO', 'Video Name': 'Eminem - Walk On Water (Audio) ft. Beyoncé', 'Category ID': 10, 'Views': 17158579, 'Likes': 787425, 'Dislikes': 43420, 'Number of Comments': 125882, 'Category Name': 'Music', 'Followers': 26572348, 'Number of Videos': 82}, {'Channel Name': 'EminemVEVO', 'Video Name': 'Eminem - Walk On Water (Audio) ft. Beyoncé', 'Category ID': 10, 'Views': 20539417, 'Likes': 840642, 'Dislikes': 47715, 'Number of Comments': 124236, 'Category Name': 'Music', 'Followers': 26572348, 'Number of Videos': 82}, {'Channel Name': 'EminemVEVO', 'Video Name': 'Eminem - Walk On Water (Audio) ft. Beyoncé', 'Category ID': 10, 'Views': 22702386, 'Likes': 869304, 'Dislikes': 50018, 'Number of Comments': 123235, 'Category Name': 'Music', 'Followers': 26572348, 'Number of Videos': 82}, {'Channel Name': 'EminemVEVO', 'Video Name': 'Eminem - Walk On Water (Audio) ft. Beyoncé', 'Category ID': 10, 'Views': 24578152, 'Likes': 891283, 'Dislikes': 51978, 'Number of Comments': 125444, 'Category Name': 'Music', 'Followers': 26572348, 'Number of Videos': 82}, {'Channel Name': 'EminemVEVO', 'Video Name': 'Walk On Water/Stan/Love The Way You Lie (Medley/Live From Saturday Night Live/2017)', 'Category ID': 10, 'Views': 1535199, 'Likes': 153770, 'Dislikes': 2439, 'Number of Comments': 16875, 'Category Name': 'Music', 'Followers': 26572348, 'Number of Videos': 82}, {'Channel Name': 'EminemVEVO', 'Video Name': 'Walk On Water/Stan/Love The Way You Lie (Medley/Live From Saturday Night Live/2017)', 'Category ID': 10, 'Views': 2653677, 'Likes': 208706, 'Dislikes': 3697, 'Number of Comments': 21614, 'Category Name': 'Music', 'Followers': 26572348, 'Number of Videos': 82}, {'Channel Name': 'EminemVEVO', 'Video Name': 'Walk On Water/Stan/Love The Way You Lie (Medley/Live From Saturday Night Live/2017)', 'Category ID': 10, 'Views': 3070103, 'Likes': 222200, 'Dislikes': 4092, 'Number of Comments': 22789, 'Category Name': 'Music', 'Followers': 26572348, 'Number of Videos': 82}, {'Channel Name': 'EminemVEVO', 'Video Name': 'Walk On Water/Stan/Love The Way You Lie (Medley/Live From Saturday Night Live/2017)', 'Category ID': 10, 'Views': 3460772, 'Likes': 232830, 'Dislikes': 4464, 'Number of Comments': 23565, 'Category Name': 'Music', 'Followers': 26572348, 'Number of Videos': 82}  ... displaying 10 of 30818 total bound parameter sets ...  {'Channel Name': 'Corridor', 'Video Name': 'TactiCOOL RELOADS', 'Category ID': 24, 'Views': 345870, 'Likes': 36481, 'Dislikes': 230, 'Number of Comments': 2082, 'Category Name': 'Entertainment', 'Followers': 5306151, 'Number of Videos': 165}, {'Channel Name': 'DKDKTV', 'Video Name': 'What Koreans Think of BTS NOW? [2018 ver.] 💜', 'Category ID': 24, 'Views': 191974, 'Likes': 19681, 'Dislikes': 79, 'Number of Comments': 3414, 'Category Name': 'People & Blogs', 'Followers': 337703, 'Number of Videos': 573})]
# (Background on this error at: http://sqlalche.me/e/f405)
